# %%
GENIUS_API_TOKEN='hgHXjEpkYI85Ud6Bw2LWCwrLlYcznI3pjq0NANvSq7fDkG6Pvb9qi06S7HnJVDCs'

# Make HTTP requests
import requests
# Scrape data from an HTML document
from bs4 import BeautifulSoup, Tag
# I/O
import os
# Search and manipulate strings
import re
import shutil
from nrclex import NRCLex
import text2emotion as te
import nltk
nltk.download('omw-1.4')

# Data analyses
import pandas as pd 
# MongoDB Configuratin
import pymongo
from pymongo import MongoClient
cluster = pymongo.MongoClient("mongodb+srv://luna-admin:1234@cluster0.sbx0f.mongodb.net/emotion_recognition?retryWrites=true&w=majority")
db = cluster["emotion_recognition"]
collection = db["artists"]


# Get artist object from Genius API
def request_artist_info(artist_name, page):
    base_url = 'https://api.genius.com'
    headers = {'Authorization': 'Bearer ' + GENIUS_API_TOKEN}
    search_url = base_url + '/search?per_page=10&page=' + str(page)
    data = {'q': artist_name}
    response = requests.get(search_url, data=data, headers=headers)
    return response

# Get Genius.com song url's from artist object
def request_song_url(artist_name, song_cap):
    page = 1
    songs = []
    
    while True:
        response = request_artist_info(artist_name, page)
        json = response.json()
        # Collect up to song_cap song objects from artist
        song_info = []
        for hit in json['response']['hits']:
            if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
                song_info.append(hit)
    
        # Collect song URL's from song objects
        for song in song_info:
            if (len(songs) < song_cap):
                url = song['result']['url']
                songs.append(url)
            
        if (len(songs) == song_cap):
            break
        else:
            page += 1
        
    print('Found {} songs by {}'.format(len(songs), artist_name))
    return songs

# Scrape lyrics from a Genius.com song URL
def scrape_song_lyrics(url, artist_name):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    extractedLyrics = html.find('div', id='lyrics-root')
    content = {}
    lyrics_list = []
    emotion_list = []
    if(extractedLyrics):
        artist_name = html.find('h2').get_text()
        lyricsArray = extractedLyrics.contents
        del lyricsArray[-1]
        formattedLyrics = ''
        for x in lyricsArray:
            if(len(x.contents) > 0):
                stringsContent = list(x.strings)
                formattedStringsContent = list(dict.fromkeys(stringsContent))
                for y in formattedStringsContent:
                    if(y[0] != '['):
                        txt2EmotionEmotions = te.get_emotion(y)
                        nrcLexEmotions = NRCLex(y)
                        emotionStr = ''
                        for x in nrcLexEmotions.top_emotions:
                            if(x[1] != 0):
                                emotionStr = x[0]
                            else:
                                for key in txt2EmotionEmotions:
                                    if(txt2EmotionEmotions[key] != 0):
                                        emotionStr = key
                        if(len(emotionStr) > 0):
                            lyrics_list.append(y)
                            emotion_list.append(emotionStr)
        content = {"content": lyrics_list, "emotion": emotion_list}
        return content
    else:
        return

def Save_artist_on_DB(name, lyrics):
    doc = {
        "name": name.lower(),
        "data": lyrics
    }
    collection.insert_one(doc)
    db_to_Dataframe(name.lower())

def write_lyrics_to_file(artist_name, song_count):
    urls = request_song_url(artist_name, song_count)
    for url in urls:
        lyrics = scrape_song_lyrics(url, artist_name)
    Save_artist_on_DB(artist_name, lyrics)

def db_to_Dataframe(artist_name):
    cursor = collection.find({"name": artist_name}).sort("content")
    separate_data = {}
    verse = []
    emotions = []

    for x in cursor:
        separate_data = x['dados']
        verse = separate_data['content']
        emotions = separate_data['emotion']
    df = pd.DataFrame({'Verse': verse, 'Emotion':emotions})
    return df

def musicData(artist_name):
    if(collection.count_documents({"name":artist_name.lower()}) > 0):
        print('okay')
        return db_to_Dataframe(artist_name.lower())
    else:
        count = 100
        write_lyrics_to_file(artist_name, count)
        return db_to_Dataframe(artist_name)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\lalme\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = musicData("Blink-182")
df.head(5)
# Out:
# Found 100 songs by Blink-182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Programacao\Topicos\TrabalhoFinal\EmotionRecognitionInSongs-main\EmotionRecognitionInSongs-main\src\TrabalhoFinal.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000001?line=0'>1</a> df = musicData("Blink-182")
#       <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000001?line=1'>2</a> df.head(5)
#
# c:\Programacao\Topicos\TrabalhoFinal\EmotionRecognitionInSongs-main\EmotionRecognitionInSongs-main\src\TrabalhoFinal.ipynb Cell 1' in musicData(artist_name)
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=131'>132</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=132'>133</a>     count = 100
# --> <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=133'>134</a>     write_lyrics_to_file(artist_name, count)
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=134'>135</a>     return db_to_Dataframe(artist_name)
#
# c:\Programacao\Topicos\TrabalhoFinal\EmotionRecognitionInSongs-main\EmotionRecognitionInSongs-main\src\TrabalhoFinal.ipynb Cell 1' in write_lyrics_to_file(artist_name, song_count)
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=109'>110</a> urls = request_song_url(artist_name, song_count)
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=110'>111</a> for url in urls:
# --> <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=111'>112</a>     lyrics = scrape_song_lyrics(url, artist_name)
#     <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=112'>113</a> Save_artist_on_DB(artist_name, lyrics)
#
# c:\Programacao\Topicos\TrabalhoFinal\EmotionRecognitionInSongs-main\EmotionRecognitionInSongs-main\src\TrabalhoFinal.ipynb Cell 1' in scrape_song_lyrics(url, artist_name)
#      <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=64'>65</a> def scrape_song_lyrics(url, artist_name):
#      <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=65'>66</a>     page = requests.get(url)
# ---> <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=66'>67</a>     html = BeautifulSoup(page.text, 'html.parser')
#      <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=67'>68</a>     extractedLyrics = html.find('div', id='lyrics-root')
#      <a href='vscode-notebook-cell:/c%3A/Programacao/Topicos/TrabalhoFinal/EmotionRecognitionInSongs-main/EmotionRecognitionInSongs-main/src/TrabalhoFinal.ipynb#ch0000000?line=68'>69</a>     content = {}
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\__init__.py:362, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=359'>360</a> self.reset()
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=360'>361</a> try:
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=361'>362</a>     self._feed()
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=362'>363</a>     success = True
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=363'>364</a>     break
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\__init__.py:448, in BeautifulSoup._feed(self)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=444'>445</a> # Convert the document to Unicode.
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=445'>446</a> self.builder.reset()
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=447'>448</a> self.builder.feed(self.markup)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=448'>449</a> # Close out any unfinished strings and close all the open tags.
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=449'>450</a> self.endData()
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\builder\_htmlparser.py:392, in HTMLParserTreeBuilder.feed(self, markup)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=389'>390</a> parser.soup = self.soup
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=390'>391</a> try:
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=391'>392</a>     parser.feed(markup)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=392'>393</a>     parser.close()
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=393'>394</a> except HTMLParseError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=103'>104</a> r"""Feed data to the parser.
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=104'>105</a>
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=105'>106</a> Call this as often as you want, with as little or as much text
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=106'>107</a> as you want (may include '\n').
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=107'>108</a> """
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=108'>109</a> self.rawdata = self.rawdata + data
# --> <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=109'>110</a> self.goahead(0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:172, in HTMLParser.goahead(self, end)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=169'>170</a>     k = self.parse_starttag(i)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=170'>171</a> elif startswith("</", i):
# --> <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=171'>172</a>     k = self.parse_endtag(i)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=172'>173</a> elif startswith("<!--", i):
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=173'>174</a>     k = self.parse_comment(i)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:420, in HTMLParser.parse_endtag(self, i)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=416'>417</a>         self.handle_data(rawdata[i:gtpos])
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=417'>418</a>         return gtpos
# --> <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=419'>420</a> self.handle_endtag(elem)
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=420'>421</a> self.clear_cdata_mode()
#     <a href='file:///c%3A/Users/lalme/AppData/Local/Programs/Python/Python310/lib/html/parser.py?line=421'>422</a> return gtpos
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\builder\_htmlparser.py:187, in BeautifulSoupHTMLParser.handle_endtag(self, name, check_already_closed)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=184'>185</a>     self.already_closed_empty_element.remove(name)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=185'>186</a> else:
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/builder/_htmlparser.py?line=186'>187</a>     self.soup.handle_endtag(name)
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\__init__.py:736, in BeautifulSoup.handle_endtag(self, name, nsprefix)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=729'>730</a> """Called by the tree builder when an ending tag is encountered.
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=730'>731</a>
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=731'>732</a> :param name: Name of the tag.
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=732'>733</a> :param nsprefix: Namespace prefix for the tag.
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=733'>734</a> """
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=734'>735</a> #print("End tag: " + name)
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=735'>736</a> self.endData()
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=736'>737</a> self._popToTag(name, nsprefix)
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\__init__.py:587, in BeautifulSoup.endData(self, containerClass)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=584'>585</a> containerClass = self.string_container(containerClass)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=585'>586</a> o = containerClass(current_data)
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=586'>587</a> self.object_was_parsed(o)
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\__init__.py:608, in BeautifulSoup.object_was_parsed(self, o, parent, most_recent_element)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=603'>604</a>         previous_element = o.previous_element
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=605'>606</a> fix = parent.next_element is not None
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=607'>608</a> o.setup(parent, previous_element, next_element, previous_sibling, next_sibling)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=609'>610</a> self._most_recent_element = o
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/__init__.py?line=610'>611</a> parent.contents.append(o)
#
# File c:\Programacao\Topicos\env\lib\site-packages\bs4\element.py:184, in PageElement.setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/element.py?line=180'>181</a>     self.previous_element.next_element = self
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/element.py?line=182'>183</a> self.next_element = next_element
# --> <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/element.py?line=183'>184</a> if self.next_element is not None:
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/element.py?line=184'>185</a>     self.next_element.previous_element = self
#     <a href='file:///c%3A/Programacao/Topicos/env/lib/site-packages/bs4/element.py?line=186'>187</a> self.next_sibling = next_sibling
#
# KeyboardInterrupt:

# %%
df.describe()
# Out:
#        Verse  Emotion
# count    0.0      0.0
# mean     NaN      NaN
# std      NaN      NaN
# min      NaN      NaN
# 25%      NaN      NaN
# 50%      NaN      NaN
# 75%      NaN      NaN
# max      NaN      NaN
